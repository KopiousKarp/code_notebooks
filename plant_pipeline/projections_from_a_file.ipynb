# %%
import pickle
import numpy as np
with open('embeddings.pkl', 'rb') as file:
    all_embeddings = pickle.load(file)

flattened_list = []
for sublist in all_embeddings[:120]:
    flattened_list.extend(sublist)
del all_embeddings
from sklearn.manifold import TSNE
flattened_array = np.array(flattened_list)
tsne = TSNE(n_components = 3, random_state=0)
projections = tsne.fit_transform(flattened_array)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[1], line 3
#       1 import pickle
#       2 import numpy as np
# ----> 3 with open('embeddings.pkl', 'rb') as file:
#       4     all_embeddings = pickle.load(file)
#       6 flattened_list = []
#
# File /opt/sam2_env/lib/python3.10/site-packages/IPython/core/interactiveshell.py:324, in _modified_open(file, *args, **kwargs)
#     317 if file in {0, 1, 2}:
#     318     raise ValueError(
#     319         f"IPython won't let you open fd={file} by default "
#     320         "as it is likely to crash IPython. If you know what you are doing, "
#     321         "you can use builtins' open."
#     322     )
# --> 324 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'embeddings.pkl'

# %%
import matplotlib.pyplot as plt

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

x = [point[0] for point in projections]
y = [point[1] for point in projections]
z = [point[2] for point in projections]

ax.scatter3D(x, y, z, c='r', marker='o')

ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_zlabel('Z')

plt.show()
